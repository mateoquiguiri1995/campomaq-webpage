# %%
import os
from dotenv import load_dotenv, find_dotenv
from pymongo import MongoClient
import pandas as pd
from pymongo.server_api import ServerApi

# Load environment variables
load_dotenv(find_dotenv())

# Connect to MongoDB
mongo_uri = os.environ['MONGO_URI']
client = MongoClient(mongo_uri, server_api=ServerApi('1'))

# %% [markdown]
# # TOP SALES PRODUCTS

# %%
# TOP SALES PRODUCTS
cm_env = os.environ.get('CM_ENV', 'dev')
if cm_env == 'prod':
    collection = client["campomaq"]["cm_top_sales_products"]
else:
    collection = client["campomaq_test"]["cm_top_sales_products"]

# Read all documents from the collection
cursor = collection.find({})
df_top_sales_prods = pd.DataFrame(list(cursor))

# %%
df_top_sales_prods
# Out:
#                            _id product_code  \
# 0     68c1c789c1cb16f9f3086e6b   408-0009SI
# 1     68c1c789c1cb16f9f3086e6c     700-0001
# 2     68c1c789c1cb16f9f3086e6d     700M-578
# 3     68c1c789c1cb16f9f3086e6e   700M-490SI
# 4     68c1c789c1cb16f9f3086e6f   311-0012SI
# ...                        ...          ...
# 2606  68c1c789c1cb16f9f3087899    412-0037A
# 2607  68c1c789c1cb16f9f308789a     700M-311
# 2608  68c1c789c1cb16f9f308789b     440-0051
# 2609  68c1c789c1cb16f9f308789c     408-0032
# 2610  68c1c789c1cb16f9f308789d     403-0191
#
#                                            product_name      brand_name  \
# 0                 MOTOCULTOR TF545DE ARRANQUE ELECTRICO       HUSQVARNA
# 1                                    MOTOCULTOR TKC-450      MITSUBISHI
# 2                        MOTOCULTOR TOPO Y LEVANTACAMAS  VARIOS MOTORES
# 3     CUCHILLA CURVA IZQUIERDA APORCAR MOTOCULTOR TF...       HUSQVARNA
# ...

# %%
df_top_sales_prods = df_top_sales_prods[["product_code", "main_boost", "low_value_flag", "popularity"]]

# %%
df_top_sales_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2611 entries, 0 to 2610
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_code    2611 non-null   object
#  1   main_boost      2611 non-null   int64
#  2   low_value_flag  2611 non-null   int64
#  3   popularity      2611 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 81.7+ KB

# %% [markdown]
# # PRODUCT INFO

# %%
# PRODUCTS
cm_env = os.environ.get('CM_ENV', 'dev')
if cm_env == 'prod':
    collection = client["campomaq"]["cm_products"]
else:
    collection = client["campomaq_test"]["cm_products"]

# Read all documents from the collection
cursor = collection.find({})
df_products = pd.DataFrame(list(cursor))

df_products = df_products[~df_products["category_name"].str.lower().str.contains("servicios", na=False)]
df_products = df_products[~df_products["product_name"].str.lower().str.contains("varios", na=False)]

# %%
df_products
# Out:
#                            _id  product_id product_code  category_id  \
# 0     68c1ec58f30a816cfad1c353           0            0            0
# 1     68c1ec58f30a816cfad1c354        3368     700M-024            0
# 2     68c1ec58f30a816cfad1c355        4167     700M-121            0
# 3     68c1ec58f30a816cfad1c356           1   101-0066SI            1
# 4     68c1ec58f30a816cfad1c357         803   305-0106SI            1
# ...                        ...         ...          ...          ...
# 4688  68c1ec59f30a816cfad1d5a3        4691     700B-547           35
# 4689  68c1ec59f30a816cfad1d5a4        4714     700B-112           35
# 4690  68c1ec59f30a816cfad1d5a5        4715     700B-111           35
# 4691  68c1ec59f30a816cfad1d5a6        4756   308-0014SI           35
# 4692  68c1ec59f30a816cfad1d5a7        4764     700B-280           35
#
#               category_name  \
# 0             SIN CATEGORIA
# 1             SIN CATEGORIA
# 2             SIN CATEGORIA
# ...

# %%
df_products = df_products[["product_id","product_code", "product_name", "category_name", "brand_name","price_cash", "is_spare_part"]]

# %% [markdown]
# ### Discounted and New products

# %%
rules_df = pd.read_csv("product_rules.csv")

# Step 2: Low-value and boost product flag
# -------------------
new_product_codes = rules_df.query("rule_type == 'code' and category == 'boost'")["rule_value"].tolist()

def new_product(row):
    code = row["product_code"]
    if code in new_product_codes:
        return True
    return False

df_products["new_product"] = df_products.apply(new_product, axis=1)

df_products['discount'] = 0
# Out:
# /var/folders/z_/f3rpfjgn6j1bwmghgxsm9nbm0000gn/T/ipykernel_77839/2493918737.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_products["new_product"] = df_products.apply(new_product, axis=1)
# /var/folders/z_/f3rpfjgn6j1bwmghgxsm9nbm0000gn/T/ipykernel_77839/2493918737.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_products['discount'] = 0

# %%
df_products[df_products["new_product"] == True]
# Out:
#       product_id product_code                           product_name  \
# 4201        1155   408-0009SI  MOTOCULTOR TF545DE ARRANQUE ELECTRICO
#
#      category_name brand_name  price_cash  new_product  discount
# 4201  MOTOCULTORES  HUSQVARNA      2300.0         True         0

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4693 entries, 0 to 4692
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     4693 non-null   int64
#  1   product_code   4693 non-null   object
#  2   product_name   4693 non-null   object
#  3   category_name  4693 non-null   object
#  4   brand_name     4693 non-null   object
#  5   price_cash     4693 non-null   float64
#  6   new_product    4693 non-null   bool
#  7   discount       4693 non-null   int64
# dtypes: bool(1), float64(1), int64(2), object(4)
# memory usage: 261.4+ KB

# %% [markdown]
# # IMAGE LINKS

# %%
# Select the database and collection
cm_env = os.environ.get('CM_ENV', 'dev')
if cm_env == 'prod':
    collection = client["campomaq"]["cm_images"]
else:
    collection = client["campomaq_test"]["cm_images"]

# Read all documents from the collection
cursor = collection.find({})
df_product_images = pd.DataFrame(list(cursor))

# %%
df_product_images = df_product_images[['product_id','link']]
df_product_images
# Out:
#       product_id                                               link
# 0             10  [https://campomaq.blob.core.windows.net/campom...
# 1             14  [https://campomaq.blob.core.windows.net/campom...
# 2             19  [https://campomaq.blob.core.windows.net/campom...
# 3             20  [https://campomaq.blob.core.windows.net/campom...
# 4             21  [https://campomaq.blob.core.windows.net/campom...
# ...          ...                                                ...
# 2372        4189  [https://campomaq.blob.core.windows.net/campom...
# 2373        4192  [https://campomaq.blob.core.windows.net/campom...
# 2374        4193  [https://campomaq.blob.core.windows.net/campom...
# 2375        4232  [https://campomaq.blob.core.windows.net/campom...
# 2376        4233  [https://campomaq.blob.core.windows.net/campom...
#
# [2377 rows x 2 columns]

# %%
# 2. Join products with images on product_id
prod_img_df = df_products.merge(df_product_images, on="product_id", how="left")

# 3. Join with popularity_df on product_code df_top_sales_prods
final_df = prod_img_df.merge(df_top_sales_prods, on="product_code", how="left")

# %%
final_df
# Out:
#       product_id product_code  \
# 0              0            0
# 1           3368     700M-024
# 2           4167     700M-121
# 3              1   101-0066SI
# 4            803   305-0106SI
# ...          ...          ...
# 4688        4691     700B-547
# 4689        4714     700B-112
# 4690        4715     700B-111
# 4691        4756   308-0014SI
# 4692        4764     700B-280
#
#                                            product_name  \
# 0                                                     .
# 1                          GATO HIDRAULICO TIPO BOTELLA
# 2                           TIJERA T-55C COSECHA Y PODA
# 3     DESBROZADOR FS-450/ CUCHILLA, VISERA COMPLETA,...
# 4                     DESBROZADORA B50R RIGIDA MARUYAMA
# ...                                                 ...
# 4688                                  BANDA DAYCO 15410
# 4689                      POLEA 12 X 2 RANURAS TORNEADO
# 4690                      POLEA 11 X 2 RANURAS TORNEADA
# ...

# %% [markdown]
# # OTHER VARIABLES

# %%
final_df['brand_logo'] = '/images/brands/placeholder.png'

# %% [markdown]
# # PRODUCT DESCRIPTION

# %%
import openai
from openai import OpenAI
from dotenv import load_dotenv, find_dotenv
from tqdm import tqdm
import math
import json
from concurrent.futures import ThreadPoolExecutor, as_completed


# Load environment variables
load_dotenv(find_dotenv())
tqdm.pandas()

openai.api_key = os.environ['OPENAI_API_KEY']
# Initialize client
client = OpenAI()


# Function to process one batch
def process_batch(i, batch, num_batches):
    prompt = "Write concise, bright and appealing product descriptions in spanish for an agricultural machinery e-commerce site.\n\n"
    for idx, row in batch.iterrows():
        prompt += f"Product {idx}:\n"
        prompt += f"Name: {row['product_name']}\n"
        prompt += f"Category: {row['category_name']}\n"
        prompt += f"Brand: {row['brand_name']}\n\n"
    prompt += "Return the results as JSON with keys being the product index and values being the description."

    response = client.chat.completions.create(
        model="gpt-5-nano",  # you can switch model here
        messages=[{"role": "user", "content": prompt}],
        # temperature=0.7
    )

    try:
        batch_desc = json.loads(response.choices[0].message.content)
    except Exception as e:
        print(f"⚠️ JSON parsing failed in batch {i}: {e}")
        batch_desc = {str(idx): response.choices[0].message.content for idx in batch.index}

    # 👀 Print one sample from this batch
    sample_idx = next(iter(batch.index))
    print(f"\nBatch {i+1}/{num_batches} sample → {batch_desc.get(str(sample_idx), '')[:150]}...\n")

    return batch_desc

# Main function
def generate_descriptions_multithread(df, batch_size=20, max_workers=5):
    descriptions = {}
    num_batches = math.ceil(len(df) / batch_size)

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        for i in range(num_batches):
            batch = df.iloc[i*batch_size:(i+1)*batch_size]
            futures.append(executor.submit(process_batch, i, batch, num_batches))

        for future in tqdm(as_completed(futures), total=len(futures), desc="Generating descriptions"):
            batch_desc = future.result()
            for k, v in batch_desc.items():
                descriptions[int(k)] = v

    return [descriptions[idx] for idx in df.index]

# Run with multithreading
final_df["description"] = generate_descriptions_multithread(final_df, batch_size=20, max_workers=5)
# Out:
# Generating descriptions:   0%|          | 1/235 [00:25<1:40:57, 25.89s/it]
# Batch 4/235 sample → Aceite 2T MARUYAMA 1L: lubricante de alto rendimiento para motores de dos tiempos; mezcla fácil y protección óptima para la motosierra....
# Generating descriptions:   1%|          | 2/235 [00:28<47:11, 12.15s/it]
# Batch 5/235 sample → Empaque de cilindro STIHL 051: repuesto original para motosierras, garantiza sellado perfecto y rendimiento duradero....
# Generating descriptions:   1%|▏         | 3/235 [00:32<32:09,  8.32s/it]
# Batch 1/235 sample → S.M. presenta un producto versátil y confiable: ideal para múltiples tareas en el campo....
# Generating descriptions:   2%|▏         | 4/235 [00:34<22:17,  5.79s/it]
# Batch 2/235 sample → Cortasetos 525HE4 de Husqvarna: precisión y potencia para setos exigentes, cuchillas afiladas y manejo ergonómico para un acabado profesional....
# Generating descriptions:   2%|▏         | 5/235 [00:39<21:51,  5.70s/it]
# ...

# %%
final_df
# Out:
#       product_id product_code  \
# 0              0            0
# 1           3368     700M-024
# 2           4167     700M-121
# 3              1   101-0066SI
# 4            803   305-0106SI
# ...          ...          ...
# 4688        4691     700B-547
# 4689        4714     700B-112
# 4690        4715     700B-111
# 4691        4756   308-0014SI
# 4692        4764     700B-280
#
#                                            product_name  \
# 0                                                     .
# 1                          GATO HIDRAULICO TIPO BOTELLA
# 2                           TIJERA T-55C COSECHA Y PODA
# 3     DESBROZADOR FS-450/ CUCHILLA, VISERA COMPLETA,...
# 4                     DESBROZADORA B50R RIGIDA MARUYAMA
# ...                                                 ...
# 4688                                  BANDA DAYCO 15410
# 4689                      POLEA 12 X 2 RANURAS TORNEADO
# 4690                      POLEA 11 X 2 RANURAS TORNEADA
# ...

# %% [markdown]
# # EMBEDDINGS

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import math

def process_embedding_batch(i, texts, num_batches):
    response = client.embeddings.create(
        model="text-embedding-3-large",   # or "text-embedding-3-large" for higher accuracy
        input=texts,
        dimensions=256
    )
    embeddings = [item.embedding for item in response.data]

    # 👀 Print one example vector length per batch
    print(f"Batch {i+1}/{num_batches} → got {len(embeddings)} embeddings, dim={len(embeddings[0])}")

    return embeddings

def generate_embeddings_multithread(df, batch_size=50, max_workers=5):
    """
    Generate embeddings for product_name + category_name + brand_name
    using multithreaded batching.
    """
    # texts = [
    #     f"{row['product_name']} | {row['category_name']} | {row['brand_name']}"
    #     for _, row in df.iterrows()
    # ]

    texts = [
        f"{row['product_name']} | {row['brand_name']}"
        for _, row in df.iterrows()
    ]


    embeddings = [None] * len(texts)
    num_batches = math.ceil(len(texts) / batch_size)

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        for i in range(num_batches):
            batch_texts = texts[i*batch_size:(i+1)*batch_size]
            futures.append(executor.submit(process_embedding_batch, i, batch_texts, num_batches))

        batch_start = 0
        for future in tqdm(as_completed(futures), total=len(futures), desc="Generating embeddings"):
            batch_embeddings = future.result()
            # Insert results back into correct positions
            embeddings[batch_start:batch_start+len(batch_embeddings)] = batch_embeddings
            batch_start += len(batch_embeddings)

    return embeddings

# Run and add embeddings column
final_df["embedding"] = generate_embeddings_multithread(final_df, batch_size=30, max_workers=5)
# Out:
# Generating embeddings:   1%|▏         | 2/157 [00:01<02:03,  1.26it/s]
# Batch 3/157 → got 30 embeddings, dim=256
# Batch 2/157 → got 30 embeddings, dim=256
# Batch 1/157 → got 30 embeddings, dim=256
# Batch 4/157 → got 30 embeddings, dim=256
# Generating embeddings:   3%|▎         | 5/157 [00:02<00:57,  2.66it/s]
# Batch 9/157 → got 30 embeddings, dim=256
# Generating embeddings:   4%|▍         | 7/157 [00:03<01:08,  2.19it/s]
# Batch 7/157 → got 30 embeddings, dim=256
# Batch 10/157 → got 30 embeddings, dim=256
# Generating embeddings:   6%|▌         | 9/157 [00:04<00:52,  2.80it/s]
# Batch 6/157 → got 30 embeddings, dim=256
# Batch 11/157 → got 30 embeddings, dim=256
# Batch 8/157 → got 30 embeddings, dim=256
# Generating embeddings:   8%|▊         | 13/157 [00:04<00:32,  4.50it/s]
# Batch 13/157 → got 30 embeddings, dim=256
# Batch 14/157 → got 30 embeddings, dim=256
# Batch 5/157 → got 30 embeddings, dim=256
# ...

# %%
final_df['updated_at'] = pd.Timestamp.now()
final_df['created_at'] = pd.Timestamp.now()

# %%
# New field to indicate that the product is shown in the catalog
top_100_codes = (
    df_top_sales_prods.sort_values("popularity", ascending=False)
    .head(100)["product_code"]
    .tolist()
)

# Assign True for top 100, False for others
final_df["show_in_app"] = final_df["product_code"].isin(top_100_codes)

# %%
final_df['is_spare_part'] = True

# %% [markdown]
# ### Prepare the final dataframe for MongoDB insertion

# %%
# final_df.info()
import numpy as np

def prepare_catalog_df(df: pd.DataFrame) -> pd.DataFrame:
    # --- Handle nulls ---
    # Replace NaN with None (Mongo stores None as null)
    df = df.replace({np.nan: None})
    
    # Ensure link is always a list (empty list if null)
    if "link" in df.columns:
        df["link"] = df["link"].apply(lambda x: x if isinstance(x, list) else ([] if x is None else [x]))
    
    # Replace nulls in numeric fields with 0.0
    numeric_fill_zero = ["main_boost", "low_value_flag", "popularity"]
    for col in numeric_fill_zero:
        if col in df.columns:
            df[col] = df[col].fillna(0.0)
    
    # Ensure booleans are actual Python bool
    bool_fields = ["new_product", "show_in_app","is_spare_part"]
    for field in bool_fields:
        if field in df.columns:
            df[field] = df[field].astype(bool)
    
    # --- Sort by popularity ---
    if "popularity" in df.columns:
        df = df.sort_values(by="popularity", ascending=False).reset_index(drop=True)
    
    return df

final_mongo_df = prepare_catalog_df(final_df)
# Out:
# /var/folders/z_/f3rpfjgn6j1bwmghgxsm9nbm0000gn/T/ipykernel_77839/1503058880.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(0.0)

# %%
final_mongo_df.head()
# Out:
#       product_id product_code  \
# 0           1155   408-0009SI
# 1           3189     700-0001
# 2           4482     700M-578
# 3           4285   700M-490SI
# 4            882   311-0012SI
# ...          ...          ...
# 4688        2604     700M-332
# 4689        2787    700M-976A
# 4690        3104         3104
# 4691        3105   700B-058SI
# 4692           0            0
#
#                                            product_name  \
# 0                 MOTOCULTOR TF545DE ARRANQUE ELECTRICO
# 1                                    MOTOCULTOR TKC-450
# 2                        MOTOCULTOR TOPO Y LEVANTACAMAS
# 3     CUCHILLA CURVA IZQUIERDA APORCAR MOTOCULTOR TF...
# 4                                CILINDRO BOMBA 653/655
# ...                                                 ...
# 4688         RETENEDOR GRANDE DESBROZADOR CHINO 15*35*5
# 4689                        BULON DE TIJERA PODAR FELCO
# 4690                                         700B-058SI
# ...

# %%
mongo_uri = os.environ['MONGO_URI']
client = MongoClient(mongo_uri, server_api=ServerApi('1'))

if cm_env == 'prod':
    collection = client["campomaq"]["cm_catalog"]
else:
    collection = client["campomaq_test"]["cm_catalog"]

if not final_mongo_df.empty:
    # Convert DataFrame to JSON
    records = final_mongo_df.to_dict(orient="records")
    collection.insert_many(records)
    print(f"✅ Inserted {len(records)} records into MongoDB")

else:
    print("No new data to insert.")
# Out:
# ✅ Inserted 4693 records into MongoDB

# %% [markdown]
# # New field to indicate that the product is shown in the catalogm

# %%
# Select the database and collection
cm_env = os.environ.get('CM_ENV', 'dev')
if cm_env == 'prod':
    collection = client["campomaq"]["cm_catalog"]
else:
    collection = client["campomaq_test"]["cm_catalog"]

# New field to indicate that the product is shown in the catalog
top_100_codes = (
    df_top_sales_prods.sort_values("popularity", ascending=False)
    .head(100)["product_code"]
    .tolist()
)

# Assign True for top 100, False for others
df_top_sales_prods["show_in_app"] = df_top_sales_prods["product_code"].isin(top_100_codes)

from pymongo import UpdateOne

# Build bulk operations
operations = [
    UpdateOne(
        {"product_code": row["product_code"]},
        {"$set": {"show_in_app": bool(row["show_in_app"])}}
    )
    for _, row in df_top_sales_prods.iterrows()
]
# Execute in bulk
if operations:
    result = collection.bulk_write(operations, ordered=False)
    print(f"Matched: {result.matched_count}, Modified: {result.modified_count}")
# Out:
# Matched: 2591, Modified: 2591
